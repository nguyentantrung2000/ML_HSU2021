# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
x = np.array(np.append(np.random.randint(0,3,10),np.random.randint(6,10,10)))
y = np.array(np.append(np.random.randint(0,3,10),np.random.randint(6,10,10)))

# %%
plt.scatter(x,y)
plt.show()
