# %%
import numpy as np 
import matplotlib.pyplot as plt
from sklearn import datasets, linear_model

# %%
X = np.array([[3,2]]).T
Y = np.array([1,4])
dt = np.arange(0,10)

# %%
regr=linear_model.LinearRegression()
regr.fit(X,Y)
# Out:
# LinearRegression()

# %%
# intercept a 
#coef b
print('y = ', np.round(regr.intercept_,3),'x + ', np.round(regr.coef_[0],3 ))
# Out:
# y =  10.0 x +  -3.0

# %%
Y_Predict = regr.predict(X)
Y_Predict1 = regr.predict(dt.reshape(-1,1))
plt.plot(X,Y_Predict, c='red')
plt.plot(dt,Y_Predict1, c='red')
plt.scatter(X,Y, c='blue')

# %%
Y_Predict = regr.predict(X)
Y_Predict1 = regr.predict(dt.reshape(-1,1))
plt.plot(X,Y_Predict, c='red')
plt.plot(dt,Y_Predict1, c='red')
plt.scatter(X,Y, c='blue')

# %% [markdown]
# # Bài 2

# %%
import pandas as pd
df = pd.read_csv('data_OOP.csv')
print(df)
# Out:
#     Diem GK  Diem CK
# 0       6.3      7.0
# 1       6.7      7.0
# 2       6.0      7.5
# 3       7.8      7.0
# 4       9.5      8.5
# 5       8.5      8.0
# 6       8.5      6.0
# 7       8.3      9.5
# 8       9.0      8.5
# 9       8.5      6.0
# 10      8.7      8.0
# 11      9.3      6.0
# 12      7.2      6.0
# 13      8.7      7.5
# 14      8.8      7.0
# 15      8.3      6.0
# 16      9.3      9.0
# 17      7.7      9.0
# 18      7.0      6.0
# 19      8.0      6.0
# 20      7.8      6.0

# %%
X = df['Diem GK'].values.reshape(-1,1)
Y = df['Diem CK'].values.reshape(-1,1)

# %%
plt.scatter(X,Y, c='blue')

# %%
X_train = np.array(df.iloc[:15,[0]])
Y_train = np.array(df.iloc[:15,[1]])
X_test = np.array(df.iloc[15:21,[0]])
Y_test = np.array(df.iloc[15:21,[1]])

# %%
regr=linear_model.LinearRegression()
regr.fit(X_train,Y_train) #y= b0 + b1X
# Out:
# LinearRegression()

# %%
b0=regr.intercept_
b1=regr.coef_
print(np.round(b0[0],3))
print(np.round(b1[0],3))
print('y = ', np.round(regr.intercept_[0],3) ,'x + ', np.round(regr.coef_[0][0],3) )
# Out:
# 5.814
# [0.183]
# y =  5.814 x +  0.183

# %%
Y_Predict_Tr = regr.predict(X_train)
Y_Predict_T = regr.predict(X_test)
plt.plot(X_train,Y_Predict_Tr, c='green')
plt.scatter(X_train,Y_train, c='yellow')
plt.scatter(X_test,Y_test, c='blue')
plt.scatter(X_test,Y_Predict_T, c='red')

# %%
Y_Predict1 = regr.predict(X_test)
print(Y_Predict1[:6])
# Out:
# [[7.33294819]
#  [7.51599368]
#  [7.2231209 ]
#  [7.09498905]
#  [7.27803454]
#  [7.24142544]]

# %%
# rmse tap test
import sklearn.metrics as sm
mse = sm.mean_squared_error(Y_test,Y_Predict1)
rmse = np.sqrt(mse)
print(np.round(rmse,3))
# Out:
# 1.385

# %%
# rmse tap train
mse1 = sm.mean_squared_error(Y_train,Y_Predict)
rmse1 = np.sqrt(mse1)
print(np.round(rmse1,3))
# Out:
# 1.012

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.3)

# %%
mse = sm.mean_squared_error(Y_test,Y_Predict1)
rmse = np.sqrt(mse)
print(np.round(rmse,3))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-dd070576cd5e> in <module>
# ----> 1 mse = sm.mean_squared_error(Y_test,Y_Predict1)
#       2 rmse = np.sqrt(mse)
#       3 print(np.round(rmse,3))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_regression.py in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     333     0.825...
#     334     """
# --> 335     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     336         y_true, y_pred, multioutput)
# ...

# %%
mse1 = sm.mean_squared_error(Y_train,Y_Predict)
rmse1 = np.sqrt(mse1)
print(np.round(rmse1,3))

# %% [markdown]
# # KNN

# %%
df = pd.read_csv('data_iris.csv').sample(n=60)
df.head()
# Out:
#      sepallength  sepalwidth  petallength  petalwidth             name
# 23           5.1         3.3          1.7         0.5      Iris-setosa
# 25           5.0         3.0          1.6         0.2      Iris-setosa
# 30           4.8         3.1          1.6         0.2      Iris-setosa
# 53           5.5         2.3          4.0         1.3  Iris-versicolor
# 149          5.9         3.0          5.1         1.8   Iris-virginica
# 7            5.0         3.4          1.5         0.2      Iris-setosa
# 8            4.4         2.9          1.4         0.2      Iris-setosa
# 77           6.7         3.0          5.0         1.7  Iris-versicolor
# 127          6.1         3.0          4.9         1.8   Iris-virginica
# 34           4.9         3.1          1.5         0.1      Iris-setosa
# 11           4.8         3.4          1.6         0.2      Iris-setosa
# 40           5.0         3.5          1.3         0.3      Iris-setosa
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-419b2ee94d18> in <module>
#       1 df.head()
# ----> 2 df.shape()
#
# TypeError: 'tuple' object is not callable
