# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import metrics
from sklearn.neighbors import KNeighborsClassifier
import sklearn.model_selection as ms

# %%
X = np.array([[6.8, 3.2, 5.9, 2.3],
[6.7, 3.3, 5.7, 2.5],
[6.7, 3.0, 5.2, 2.3],
[6.3, 2.5, 5.0, 1.9],
[6.5,3,5.2, 2],
[6.3,3.3,6,2.5],
[5.8,2.7,5.1,1.9],
[7.1,3,5.9,2.1],
[6.3,2.9,5.6,1.8],
[6.5,3,5.8,2.2],
[6,2.9,4.5,1.5],
[5.7,2.6,3.5,1],
[5.5,2.4,3.8,1.1],
[5.5,2.4,3.7,1],
[5.8,2.7,3.9,1.2],
[6,2.7,5.1,1.6],
[5.4,3,4.5,1.5],
[6,3.4,4.5,1.6],
[6.7,3.1,4.7,1.5],
[6.3,2.3,4.4,1.3],
[5.6,3,4.1,1.3],
[5.7,3.8,1.7,0.3],
[5.1,3.8,1.5,0.3],
[5.4,3.4,1.7,0.2],
[5.1,3.7,1.5,0.4],
[4.6,3.6,1,0.2],
[5.1,3.3,1.7,0.5],
[4.8,3.4,1.9,0.2],
[5,3,1.6,0.2],
[5,3.4,1.6,0.4],
])

Y = np.array([

"Iris-virginica",
"Iris-virginica",
"Iris-virginica",
"Iris-virginica",
"Iris-virginica",
"Iris-virginica",
"Iris-virginica",
"Iris-virginica",
"Iris-virginica",
"Iris-virginica",
"Iris-versicolor",
"Iris-versicolor",
"Iris-versicolor",
"Iris-versicolor",
"Iris-versicolor",
"Iris-versicolor",
"Iris-versicolor",
"Iris-versicolor",
"Iris-versicolor",
"Iris-versicolor",
"Iris-setosa",
"Iris-setosa",     
"Iris-setosa",
"Iris-setosa",
"Iris-setosa",
"Iris-setosa",
"Iris-setosa",
"Iris-setosa",
"Iris-setosa",
"Iris-setosa",
])

# %%
fig = plt.figure(figsize=(5,5))
axes = fig.add_subplot(111)
X_sp = X[0]
Y_sp = X[1]

for i in range(len(X)):
    color = 'green' if Y[i] == 'R' else 'yellow'
    axes.scatter(movies[i][0], movies[i][1], c=color)
    
axes.scatter(X_sp, Y_sp, c='red')
axes.set_xlabel('X')
axes.set_ylabel('Y')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-17-fac1810d792b> in <module>
#       6 for i in range(len(X)):
#       7     color = 'green' if Y[i] == 'R' else 'yellow'
# ----> 8     axes.scatter(movies[i][0], movies[i][1], c=color)
#       9
#      10 axes.scatter(X_sp, Y_sp, c='red')
#
# IndexError: index 6 is out of bounds for axis 0 with size 6

# %%
### goi ham va train 
knn5 = KNeighborsClassifier(n_neighbors=15)
knn5.fit(X_train, Y_train)

# %%
Y_pred = knn5.predict(X_test)

# %%
accs = []
k_grid = range(1,50,1)
for k in k_grid:
    knn = neighbors.KNeighborsClassifier(n_neighbors = k)
    knn.fit(X_train,Y_train)
    Y_pred = knn.predict(X_test)
    score = metrics.accuracy_score(Y_test, Y_pred)
    accs.append(score)
    if score == 1: print('Accuracy 100% with k =', k)
