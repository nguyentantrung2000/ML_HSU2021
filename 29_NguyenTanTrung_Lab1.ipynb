# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([167,170,149,165,155,180,166,146,159,185,145,168,172,181,169,161,162,182,141,155])
y = np.array([86,74,66,78,68,79,90,73,70,88,66,84,67,84,77,61,70,95,87,65])

colors = np.random.rand(20)
area = (40 * np.random.rand(20))**2 

plt.xlim(140,200)
plt.ylim(60,100)
plt.scatter(x,y,s=area)
plt.xlabel("X")
plt.ylabel("Y")
plt.show()
